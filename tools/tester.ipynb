# %%
import formatter as fmt
import os

directories = [x[0] for x in os.walk('../testData/')]
# Out:
# ['../testData/',
#  '../testData/AICoop',
#  '../testData/Custom',
#  '../testData/HL',
#  '../testData/QM',
#  '../testData/TL',
#  '../testData/UD']

# %%
dictInitData
# Out:
# {'m_syncLobbyState': {'m_gameDescription': {'m_defaultAIBuild': 0,
#    'm_defaultDifficulty': 7,
#    'm_gameCacheName': 'Dflt',
#    'm_gameOptions': {'m_advancedSharedControl': False,
#     'm_amm': True,
#     'm_ammId': 50001,
#     'm_battleNet': True,
#     'm_clientDebugFlags': 289,
#     'm_competitive': True,
#     'm_cooperative': False,
#     'm_fog': 0,
#     'm_heroDuplicatesAllowed': True,
#     'm_lockTeams': True,
#     'm_noVictoryOrDefeat': False,
#     'm_observers': 0,
#     'm_practice': False,
#     'm_randomRaces': False,
#     'm_teamsTogether': False,
#     'm_userDifficulty': 0},
#    'm_gameSpeed': 4,
#    'm_gameType': 0,
#    'm_hasExtensionMod': False,
#    'm_isBlizzardMap': True,
#    'm_isCoopMode': False,
#    'm_isPremadeFFA': False,
#    'm_mapAuthorName': '1-Hero-1-26',
#    'm_mapFileSyncChecksum': 323297327,
#    'm_mapSizeX': 248,
#    'm_mapSizeY': 208,
#    'm_maxColors': 16,
#    'm_maxControls': 1,
#    'm_maxObservers': 6,
# ...
